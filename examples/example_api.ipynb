# %%
# example of desired API

import goddard

# generate a rocket problem

prob = RocketProblem(
    fuel="kerosene",
    oxidizer="O2(L)",
    pressure=[5e6],
    OF_ratio=[1.1,2.3,2.4],
    super=[3,5,10,15,20],
    nozzle=FrozenNozzle(),
    combustor=FiniteAreaCombustor()
)

solution = solve(prob, solveroptions=None)

solution.report()

solution.isp #provides isp in a numpy array for convenient processing
solution.super

# %% [markdown]
# ## Using other thermodynamic databases or custom data
#
# There will also be functionality to use other databases, if NASA9 doesn't cut it.

# %%
goddard.data.add_source("my_data_file.yaml")
